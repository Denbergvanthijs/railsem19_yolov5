# %% [markdown]
# # Train YOLOv5 on RailSem19
#
# This notebook is based on the [YOLOv5 tutorial](https://colab.research.google.com/github/ultralytics/yolov5/blob/master/tutorial.ipynb).
#
# ---
#
# ## Setup
#
# Clone YOLOv5, install dependencies and check PyTorch and GPU:

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

from yolov5 import utils
display = utils.notebook_init()  # checks

# %%
# %cd ../
# !git clone https://github.com/Denbergvanthijs/railsem19_yolov5.git

# %% [markdown]
# Load Tensorboard and Weights & Biases (both optional):

# %%
# Tensorboard  (optional)
# %load_ext tensorboard
# %tensorboard --logdir runs/train

# %%
# Weights & Biases  (optional)
# %pip install -q wandb
import wandb
wandb.login()

# %% [markdown]
# Mount personal Google Drive:

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Copy training data from Google Drive to local disk:

# %%
# !cp ./drive/MyDrive/rs19_person_semseg ./rs19_person_semseg -r

# %% [markdown]
# ## Training
#
# Change the following line in `rs19_person_semseg.yaml`:
#
# ```yaml
# path: ./rs19_person_semseg
# ```

# %%
# !python ./yolov5/train.py --batch-size 64 --epochs 50 --data ./railsem19_yolov5/data/rs19_person_semseg.yaml --weights yolov5s.pt --single-cls --cache --hyp ./railsem19_yolov5/data/hyp_evolve.yaml

# %% [markdown]
# ## Hyperparameter optimalisation
#
# Change the following line in `rs19_person_semseg.yaml`:
#
# ```yaml
# path: ./rs19_person_semseg
# ```

# %%
# !python ./yolov5/train.py --batch-size 64 --epochs 10 --data ./railsem19_yolov5/data/rs19_person_semseg.yaml --weights yolov5s.pt --single-cls --cache --evolve 40 --hyp "./railsem19_yolov5/data/hyp_evolve.yaml"
